# %%
import pandas as pd
import seaborn as sns

# %%
cc = pd.read_csv('creditcard.csv')

# %%
cc.head()
# Out:
#    id        V1        V2        V3        V4        V5        V6        V7  \
# 0   0 -0.260648 -0.469648  2.496266 -0.083724  0.129681  0.732898  0.519014
# 1   1  0.985100 -0.356045  0.558056 -0.429654  0.277140  0.428605  0.406466
# 2   2 -0.260272 -0.949385  1.728538 -0.457986  0.074062  1.419481  0.743511
# 3   3 -0.152152 -0.508959  1.746840 -1.090178  0.249486  1.143312  0.518269
# 4   4 -0.206820 -0.165280  1.527053 -0.448293  0.106125  0.530549  0.658849
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0 -0.130006  0.727159  ... -0.110552  0.217606 -0.134794  0.165959  0.126280
# 1 -0.133118  0.347452  ... -0.194936 -0.605761  0.079469 -0.577395  0.190090
# 2 -0.095576 -0.261297  ... -0.005020  0.702906  0.945045 -1.154666 -0.605564
# 3 -0.065130 -0.205698  ... -0.146927 -0.038212 -0.214048 -1.893131  1.003963
# 4 -0.212660  1.049921  ... -0.106984  0.729727 -0.161666  0.312561 -0.414116
#
# ...

# %%
cc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568630 entries, 0 to 568629
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id      568630 non-null  int64
#  1   V1      568630 non-null  float64
#  2   V2      568630 non-null  float64
#  3   V3      568630 non-null  float64
#  4   V4      568630 non-null  float64
#  5   V5      568630 non-null  float64
#  6   V6      568630 non-null  float64
#  7   V7      568630 non-null  float64
#  8   V8      568630 non-null  float64
#  9   V9      568630 non-null  float64
#  10  V10     568630 non-null  float64
#  11  V11     568630 non-null  float64
#  12  V12     568630 non-null  float64
#  13  V13     568630 non-null  float64
#  14  V14     568630 non-null  float64
#  15  V15     568630 non-null  float64
#  16  V16     568630 non-null  float64
#  17  V17     568630 non-null  float64
#  18  V18     568630 non-null  float64
#  19  V19     568630 non-null  float64
# ...

# %%
cc.describe()
# Out:
#                   id            V1            V2            V3            V4  \
# count  568630.000000  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05
# mean   284314.500000 -5.638058e-17 -1.323544e-16 -3.518788e-17 -2.879008e-17
# std    164149.486121  1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00
# min         0.000000 -3.495584e+00 -4.996657e+01 -3.183760e+00 -4.951222e+00
# 25%    142157.250000 -5.652859e-01 -4.866777e-01 -6.492987e-01 -6.560203e-01
# 50%    284314.500000 -9.363846e-02 -1.358939e-01  3.528579e-04 -7.376152e-02
# 75%    426471.750000  8.326582e-01  3.435552e-01  6.285380e-01  7.070047e-01
# max    568629.000000  2.229046e+00  4.361865e+00  1.412583e+01  3.201536e+00
#
#                  V5            V6            V7            V8            V9  \
# count  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05
# mean   7.197521e-18 -3.838678e-17 -3.198898e-17  2.069287e-17  9.116859e-17
# ...

# %%
cc.isnull().sum()
# Out:
# id        0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
cc.duplicated().sum()
# Out:
# 0

# %%
fraud = cc[cc['Class'] == 1]
fraud_percent = len(fraud)/len(cc)
print(fraud_percent)
# Out:
# 0.5

# %%
genuine = cc[cc['Class'] != 1]

# %%
print(genuine.shape)
print(fraud.shape)
# Out:
# (284315, 31)
# (284315, 31)

# %%
import matplotlib.pyplot as plt

def plot_histograms(dataframe, bins=30, figsize=(15, 15)):
    ### plots histograms for every numerical feature of a dataset ### 
    num_columns = len(dataframe.columns)
    
    num_rows = 8
    num_cols = 4

    fig, axes = plt.subplots(num_rows, num_cols, figsize=figsize)
    
    axes = axes.flatten()
    
    for i, column in enumerate(dataframe.columns):
        ax = axes[i]
        
        dataframe[column].plot(kind='hist', bins=bins, ax=ax, edgecolor='black', color='darkviolet')
        
        ax.set_title(f'Distribution - {column}')
        ax.set_xlabel(column)
        ax.set_ylabel('Frequency')
    fig.tight_layout()

# %%
sns.set_style('darkgrid')
plot_histograms(cc)
plt.savefig('hist.png',bbox_inches = 'tight', pad_inches = 1)

# %% [markdown]
# We don't have any missing data, we don't have any duplicates, and our classes are perfectly balanced, as all things should be. It also does not look like we have many outliers. You can see there may be a few outliers in features V8, V21, and V22, but they seem to be very small in frequency and do not worry me.
#
# Looks like the data was well-cleaned prior to being uploaded to Kaggle. The data was also scaled using PCA before upload.
#
# I believe this was primarily done to ensure complete anonymity, given the sensitive nature of the data. Given the scaling, it seems pretty much impossible to infer what these features may have been prior to scaling (like time of transaction, location of transaction, things like that).
#
# I imagine in a real scenario, even if I didn't have access to the real features, someone would. This is important to keep in mind throughout this entire project.
